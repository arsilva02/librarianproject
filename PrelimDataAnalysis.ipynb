# %% [markdown]
# <a href="https://colab.research.google.com/github/arsilva02/librarianproject/blob/main/PrelimDataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import pandas as pd

# %%
#get df
df = pd.read_csv('storygraphExport.csv')

# %% [markdown]
# Firstly, we can look at the columns of this df. Our training and testing data are all within this df. We want to predict on 'Star Rating', which will be our y. Some of the books have been read, but not rated (most of these are manga, which I don't really want to include in my system since I read these on a very specific basis, so we'll be sure to remove these). So instead of looking at Read Count > 1, we will define our read books as has a star rating

# %%
df.columns
# Out:
# Index(['Title', 'Authors', 'Contributors', 'ISBN/UID', 'Format', 'Read Status',
#        'Date Added', 'Last Date Read', 'Dates Read', 'Read Count', 'Moods',
#        'Pace', 'Character- or Plot-Driven?', 'Strong Character Development?',
#        'Loveable Characters?', 'Diverse Characters?', 'Flawed Characters?',
#        'Star Rating', 'Review', 'Content Warnings',
#        'Content Warning Description', 'Tags', 'Owned?'],
#       dtype='object')

# %%
#rows with star rating
read_books = df[~df['Star Rating'].isna()]
read_books[['Title','Star Rating','Review']]
# Out:
#                                  Title  Star Rating  \
# 21                           Big Swiss         4.75
# 30                             Orbital         2.50
# 53               The Covenant of Water         3.75
# 57                          Las Madres         4.00
# 66                       Nightcrawling         2.75
# ..                                 ...          ...
# 699  The Invisible Life of Addie LaRue         3.00
# 700                           The Deep         4.50
# 705                         Yellowface         2.00
# 720                              Babel         2.75
# 722                 This Ravenous Fate         3.50
#
#                                                 Review
# 21   <div>the audience for this book imo is very ni...
# 30   <div>tbh this would have been way better as a ...
# 53   <div>there are some very engaging and some ver...
# 57   <div>so ill start off with some things that i ...
# 66   <div>so i want to say it is really amazing tha...
# ...

# %%
read_books.sort_values(by='Star Rating', ascending=False)[:15]['Review'].values
# Out:
# array(['<div>the ones who walk away from omelas but as a novel about how racism systematically will fail everyone. no wonder people keep trying to ban it :/</div>',
#        nan,
#        '<div>this is a book where you need to be dealing with grief to get the full expierence of; if you are in the same stage of magical thinking as didion, i think this book will speak volumes. otherwise, i can understand why some people think its repetitive and miss out on some of the nuances that didion lays out through her processing</div>',
#        "<div>So I read this book right after Orbital and honestly I think this book used it's inherent structure as a fiction book sooo much better than Orbital did. I cried multiple times, it's honestly a very challenging read emotionally so probably not best read if you're emotionally struggling right now. It's so bleak but also hopeful</div>",
#        nan,
# ...
